# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import pandas as pd
df=pd.read_csv(r'D:\Internship\Week1\Task1-Week1\data\raw\content_refresh_anonymized.csv')

# %%
print (df)
# Out:
#                  content_id          client_id  search_volume  competition  \
# 0      content_304f48230142  client_f369cb89fc           10.0         0.67
# 1      content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2      content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3      content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4      content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
# ...                     ...                ...            ...          ...
# 29995  content_c322796023c8  client_e29c9c180c           10.0         0.05
# 29996  content_526572edb3fa  client_7f2253d7e2            0.0         0.00
# 29997  content_38112bdd0c6e  client_349c41201b           10.0         1.00
# 29998  content_ab26273a7e7a  client_19581e27de           10.0         0.00
# 29999  content_887020f20b5e  client_6208ef0f77            0.0         0.00
#
# ...

# %%
print("Rows:", df.shape[0])
# Out:
# Rows: 30000

# %%
print("Columns:", df.shape[1])
# Out:
# Columns: 44

# %%
print("Unique Clients:", df["client_id"].nunique())
# Out:
# Unique Clients: 32

# %%
print("Average Search Volume:", df["search_volume"].mean())
# Out:
# Average Search Volume: 158.88239139909922

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **Lane:** Ranking Signal Analysis
#
# I chose the **Ranking Signal Analysis** lane because I want to understand which content and search signals are associated with page performance. By analyzing metrics such as impressions, clicks, CTR, engagement, and search volume, I can identify patterns that help explain content performance. These insights can support better content and SEO decisions.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Research Question:**
# Which content and search signals are most strongly associated with better page performance?
# **Decision:**
# This project helps determine which content and search signals should be considered when evaluating page performance.
#
# **Unit of Analysis:**
# One content page.
#
# **Output:**
# A ranked analysis of the content and search signals associated with page performance.
#
# **Action:**
# The content and SEO team can use these insights to prioritize content improvements and optimization efforts.
#
# **Cost of a Wrong Recommendation:**
# If the analysis identifies the wrong signals, the team may spend time and resources improving the wrong pages while missing better opportunities.
#
# **Why Data or ML?**
# Content performance depends on multiple factors that interact in complex ways. Data analysis and machine learning can identify meaningful patterns that are difficult to discover using simple rules.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df=pd.read_csv(r'D:\Internship\Week1\Task1-Week1\data\raw\content_refresh_anonymized.csv')

# %%
print("Average Impressions (90d):", round(df["impressions_90d"].mean(), 2))
print("Average CTR:", round(df["ctr"].mean(), 2))
print("Unique Clients:", df["client_id"].nunique())
# Out:
# Average Impressions (90d): 5200.37
# Average CTR: 0.51
# Unique Clients: 32

# %%
import pandas as pd


print("Total Pages:", df.shape[0])
print("Total Features:", df.shape[1])
print("Unique Clients:", df["client_id"].nunique())
# Out:
# Total Pages: 30000
# Total Features: 44
# Unique Clients: 32

# %% [markdown]
# The starter dataset contains **30,000 content pages** and **44 features**. These data provide a strong foundation for analyzing relationships between content and search performance. Additional statistics such as the number of unique clients and average search volume will also be explored to support this research question.
#
# ---

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project identifies **observed patterns** between content and search signals and page performance. The findings provide **directional insights** and **decision support** for content optimization. However, this project **cannot prove causation**, **cannot predict Google's ranking algorithm**, and **cannot guarantee that improving a specific signal will improve page performance**.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
